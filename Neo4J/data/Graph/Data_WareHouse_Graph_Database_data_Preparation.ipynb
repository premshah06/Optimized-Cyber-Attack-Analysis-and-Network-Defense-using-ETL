# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/modified_daata.csv')

# %%
df.head()
# Out:
#                                 Flow ID     Source IP   Source Port  \
# 0  192.168.10.3-192.168.10.5-88-49182-6  192.168.10.5         49182
# 1  192.168.10.3-192.168.10.5-88-49183-6  192.168.10.5         49183
# 2  192.168.10.3-192.168.10.5-88-49184-6  192.168.10.5         49184
# 3  192.168.10.3-192.168.10.5-88-49185-6  192.168.10.5         49185
# 4  192.168.10.3-192.168.10.5-88-49186-6  192.168.10.5         49186
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.3                 88          6  4/7/2017 8:54
# 1    192.168.10.3                 88          6  4/7/2017 8:54
# 2    192.168.10.3                 88          6  4/7/2017 8:54
# 3    192.168.10.3                 88          6  4/7/2017 8:54
# 4    192.168.10.3                 88          6  4/7/2017 8:54
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# 0             640                   7                        4  ...
# ...

# %%
df.columns
# Out:
# Index(['Flow ID', ' Source IP', ' Source Port', ' Destination IP',
#        ' Destination Port', ' Protocol', ' Timestamp', ' Flow Duration',
#        ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
# ...

# %% [markdown]
# ###Source IP and Label File

# %%
SourceIP_Label=df[[' Source IP',' Source Port',' Label']]

# %%
SourceIP_Label.duplicated().value_counts()
# Out:
# True     2742616
# False     459104
# Name: count, dtype: int64

# %%
len(SourceIP_Label)
# Out:
# 3201720

# %%
#To get count of each Source IP, Source Port and Label
SourceIP_Label_uni=SourceIP_Label.value_counts().reset_index()

# %%
SourceIP_Label_uni['count'].sum()
# Out:
# 3201720

# %%
SourceIP_Label_uni.duplicated().value_counts()
# Out:
# False    459104
# Name: count, dtype: int64

# %%
SourceIP_Label_uni.column=['SourceIP','SourcePort','Label','count']
# Out:
# <ipython-input-11-a9c6610b8dd8>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   SourceIP_Label_uni.column=['SourceIP','SourcePort','Label','count']

# %%
SourceIP_Label_uni.head()
# Out:
#        Source IP   Source Port   Label  count
# 0  192.168.10.50            80  BENIGN  38292
# 1  192.168.10.17           123  BENIGN   8665
# 2    72.21.91.29            80  BENIGN   7548
# 3  192.168.10.19           123  BENIGN   6782
# 4  192.168.10.50            21  BENIGN   6389

# %%
SourceIP_Label_uni.to_csv('SourceIP_Label.csv',index=False)

# %% [markdown]
# ###Destination File and Label File

# %%
DestIP_Label=df[[' Destination IP',' Destination Port',' Label']]
DestIP_Label.head()
# Out:
#   Destination IP  Destination Port   Label
# 0   192.168.10.3                88  BENIGN
# 1   192.168.10.3                88  BENIGN
# 2   192.168.10.3                88  BENIGN
# 3   192.168.10.3                88  BENIGN
# 4   192.168.10.3                88  BENIGN

# %%
len(DestIP_Label)
# Out:
# 3201720

# %%
DestIP_Label.duplicated().value_counts()
# Out:
# True     2985721
# False     215999
# Name: count, dtype: int64

# %%
DestIP_Label_uni=DestIP_Label.value_counts().reset_index()
DestIP_Label_uni.head()
# Out:
#    Destination IP   Destination Port     Label   count
# 0    192.168.10.3                 53    BENIGN  719881
# 1    192.168.10.1                 53    BENIGN  320561
# 2   192.168.10.50                 80  DoS Hulk  231073
# 3   192.168.10.50                 80      DDoS  128024
# 4    178.255.83.1                 80    BENIGN   21767

# %%
DestIP_Label_uni.duplicated().value_counts()
# Out:
# False    215999
# Name: count, dtype: int64

# %%
DestIP_Label_uni['count'].sum()
# Out:
# 3201720

# %%
DestIP_Label_uni.columns=['DestinationIP','DestinationPort','Label','count']
DestIP_Label_uni.head()
# Out:
#    DestinationIP  DestinationPort     Label   count
# 0   192.168.10.3               53    BENIGN  719881
# 1   192.168.10.1               53    BENIGN  320561
# 2  192.168.10.50               80  DoS Hulk  231073
# 3  192.168.10.50               80      DDoS  128024
# 4   178.255.83.1               80    BENIGN   21767

# %%
DestIP_Label_uni.to_csv('DestIP_Label.csv',index=False)

# %% [markdown]
# ###Creating a file for Type of Attack and Protocol Type

# %%
protocol_type=df[[' Protocol',' Label']]
protocol_type.head()
# Out:
#    Protocol   Label
# 0         6  BENIGN
# 1         6  BENIGN
# 2         6  BENIGN
# 3         6  BENIGN
# 4         6  BENIGN

# %%
len(protocol_type)
# Out:
# 3201720

# %%
protocol_type.duplicated().value_counts()
# Out:
# True     3201705
# False         15
# Name: count, dtype: int64

# %%
protocol_type_uni=protocol_type.value_counts().reset_index()
protocol_type_uni.head()
# Out:
#     Protocol     Label    count
# 0          6    BENIGN  1391687
# 1         17    BENIGN  1081960
# 2          6  PortScan   317846
# 3          6  DoS Hulk   231073
# 4          6      DDoS   128027

# %%
protocol_type_uni['count'].sum()
# Out:
# 3201720

# %%
len(protocol_type_uni)
# Out:
# 15

# %%
protocol_type_uni.duplicated().value_counts()
# Out:
# False    15
# Name: count, dtype: int64

# %%
protocol_type_uni.columns=['Protocol','Label','count']
protocol_type_uni.head()
# Out:
#    Protocol     Label    count
# 0         6    BENIGN  1391687
# 1        17    BENIGN  1081960
# 2         6  PortScan   317846
# 3         6  DoS Hulk   231073
# 4         6      DDoS   128027

# %%
protocol_type_uni.to_csv('protocol_type.csv',index=False)

# %% [markdown]
# ###TO create file to get the relationship between the packets and type of attack

# %%
#Lets map the unique packet ID from the uni_packets to main df file

# Merge the DataFrames
new_df = pd.merge(df, uni_packets, on=[' Total Fwd Packets', ' Total Backward Packets',
       'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
       ' Fwd Packet Length Max', ' Fwd Packet Length Min',
       ' Fwd Packet Length Mean', ' Fwd Packet Length Std','Bwd Packet Length Max', ' Bwd Packet Length Min',
       ' Bwd Packet Length Mean', ' Bwd Packet Length Std',' Min Packet Length', ' Max Packet Length',
       ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',' Average Packet Size'], how='left')

# %%
packet_ID_Attack=new_df[['Packet_ID',' Label']]
packet_ID_Attack.head()
# Out:
#   Packet_ID   Label
# 0  Packet_0  BENIGN
# 1  Packet_1  BENIGN
# 2  Packet_2  BENIGN
# 3  Packet_3  BENIGN
# 4  Packet_4  BENIGN

# %%
packet_ID_Attack.duplicated().value_counts()
# Out:
# True     2801332
# False     400388
# Name: count, dtype: int64

# %%
uni_packet_ID_attack=packet_ID_Attack.value_counts().reset_index()

# %%
len(uni_packet_ID_attack)
# Out:
# 400388

# %%
uni_packet_ID_attack.duplicated().value_counts()
# Out:
# False    400388
# Name: count, dtype: int64

# %%
uni_packet_ID_attack.columns=['Packet_ID','Label','count']
uni_packet_ID_attack.head()
# Out:
#        Packet_ID     Label   count
# 0      Packet_51    BENIGN  175745
# 1  Packet_457098  PortScan  158976
# 2  Packet_710253  PortScan  155910
# 3      Packet_19    BENIGN  106639
# 4  Packet_445909    BENIGN   95663

# %%
uni_packet_ID_attack.to_csv('uni_packet_ID_attack.csv',index=False)

# %% [markdown]
# ###Detail about which source sending which packet and recieving Destination IP

# %%
Sour_Dest_Packet=new_df[[' Source IP',' Destination IP','Packet_ID']]
Sour_Dest_Packet.head()
# Out:
#       Source IP  Destination IP Packet_ID
# 0  192.168.10.5    192.168.10.3  Packet_0
# 1  192.168.10.5    192.168.10.3  Packet_1
# 2  192.168.10.5    192.168.10.3  Packet_2
# 3  192.168.10.5    192.168.10.3  Packet_3
# 4  192.168.10.5    192.168.10.3  Packet_4

# %%
Sour_Dest_Packet.duplicated().value_counts()
# Out:
# True     2562185
# False     639535
# Name: count, dtype: int64

# %%
Sour_Dest_Packet_uni=Sour_Dest_Packet.value_counts().reset_index()

# %%
Sour_Dest_Packet_uni.duplicated().value_counts()
# Out:
# False    639535
# Name: count, dtype: int64

# %%
Sour_Dest_Packet_uni.columns=['SourceIP','DestinationIP','Packet_ID','count']
Sour_Dest_Packet_uni.head()
# Out:
#      SourceIP  DestinationIP      Packet_ID   count
# 0  172.16.0.1  192.168.10.50  Packet_457098  158976
# 1  172.16.0.1  192.168.10.50  Packet_710253  155924
# 2  172.16.0.1  192.168.10.50      Packet_19   59496
# 3  172.16.0.1  192.168.10.50  Packet_455402   22974
# 4  172.16.0.1  192.168.10.50  Packet_464811   22282

# %%
Sour_Dest_Packet_uni.to_csv('Sour_Dest_Packet.csv',index=False)

# %% [markdown]
# ###To get the file for each nodes

# %%
uni_Source_IP=df[' Source IP']
uni_Source_IP.duplicated().value_counts()
# Out:
#  Source IP
# True     3185885
# False      15835
# Name: count, dtype: int64

# %%
uni_Source_IP=uni_Source_IP.drop_duplicates()
uni_Source_IP.duplicated().value_counts()
# Out:
#  Source IP
# False    15835
# Name: count, dtype: int64

# %%
uni_Source_IP.columns=['SourceIP']

# %%
uni_Source_IP.to_csv('uni_Source_IP.csv',index=False)

# %%
uni_Des_IP=df[' Destination IP']
uni_Des_IP.drop_duplicates(inplace=True)
uni_Des_IP.duplicated().value_counts()
uni_Des_IP.columns=['DestinationIP']

# %%
uni_Des_IP.to_csv('uni_Des_IP.csv',index=False)

# %%
uni_Source_Port=df[' Source Port']
uni_Source_Port.drop_duplicates(inplace=True)
uni_Source_Port.duplicated().value_counts()
uni_Source_Port.columns=['SourcePort']

# %%
uni_Source_Port.to_csv('uni_Source_Port.csv',index=False)

# %%
uni_Des_Port=df[' Destination Port']
uni_Des_Port.drop_duplicates(inplace=True)
uni_Des_Port.duplicated().value_counts()
uni_Des_Port.columns=['DestinationPort']
uni_Des_Port.to_csv('uni_Des_Port.csv',index=False)

# %%
uni_Lavel=df[' Label']
uni_Lavel.drop_duplicates(inplace=True)
uni_Lavel.duplicated().value_counts()
uni_Lavel.columns=['Label']

# %%
uni_Lavel.to_csv('uni_Label.csv',index=False)

# %%
uni_packets=df[[' Total Fwd Packets', ' Total Backward Packets',
       'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
       ' Fwd Packet Length Max', ' Fwd Packet Length Min',
       ' Fwd Packet Length Mean', ' Fwd Packet Length Std','Bwd Packet Length Max', ' Bwd Packet Length Min',
       ' Bwd Packet Length Mean', ' Bwd Packet Length Std',' Min Packet Length', ' Max Packet Length',
       ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',' Average Packet Size']]
uni_packets.head()
# Out:
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0                   7                        4                        440.0
# 1                   9                        4                        600.0
# 2                   7                        4                       2776.0
# 3                   7                        4                        452.0
# 4                   9                        4                        612.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                         358.0                   220.0
# 1                        2944.0                   300.0
# 2                        2830.0                  1388.0
# 3                         370.0                   226.0
# 4                        2944.0                   306.0
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                     0.0                62.857143              107.349008
# ...

# %%
uni_packets.duplicated().value_counts()
# Out:
# True     2801436
# False     400284
# Name: count, dtype: int64

# %%
uni_packets.drop_duplicates(inplace=True)
# Out:
# <ipython-input-122-abf1ecb261ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uni_packets.drop_duplicates(inplace=True)

# %%
uni_packets.duplicated().value_counts()
# Out:
# False    400284
# Name: count, dtype: int64

# %%
uni_packets.head()
# Out:
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0                   7                        4                        440.0
# 1                   9                        4                        600.0
# 2                   7                        4                       2776.0
# 3                   7                        4                        452.0
# 4                   9                        4                        612.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                         358.0                   220.0
# 1                        2944.0                   300.0
# 2                        2830.0                  1388.0
# 3                         370.0                   226.0
# 4                        2944.0                   306.0
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                     0.0                62.857143              107.349008
# ...

# %%
#Lets create a unique value to identify each Packet
uni_packets['Packet_ID']=['Packet_'+str(i) for i in uni_packets.index]
# Out:
# <ipython-input-125-ab3070561150>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uni_packets['Packet_ID']=['Packet_'+str(i) for i in uni_packets.index]

# %%
uni_packets.head()
uni_packets_copy=uni_packets.copy()
uni_packets_copy.columns=[['Total Fwd Packets', 'Total Backward Packets',
       'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
       'Fwd Packet Length Max', 'Fwd Packet Length Min',
       'Fwd Packet Length Mean', 'Fwd Packet Length Std','Bwd Packet Length Max', 'Bwd Packet Length Min',
       'Bwd Packet Length Mean', 'Bwd Packet Length Std',' Min Packet Length', 'Max Packet Length',
       'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance','Average Packet Size','Packet_ID']]

# %%
uni_packets_copy.head()
# Out:
#   Total Fwd Packets Total Backward Packets Total Length of Fwd Packets  \
# 0                 7                      4                       440.0
# 1                 9                      4                       600.0
# 2                 7                      4                      2776.0
# 3                 7                      4                       452.0
# 4                 9                      4                       612.0
#
#   Total Length of Bwd Packets Fwd Packet Length Max Fwd Packet Length Min  \
# 0                       358.0                 220.0                   0.0
# 1                      2944.0                 300.0                   0.0
# 2                      2830.0                1388.0                   0.0
# 3                       370.0                 226.0                   0.0
# 4                      2944.0                 306.0                   0.0
#
#   Fwd Packet Length Mean Fwd Packet Length Std Bwd Packet Length Max  \
# ...

# %%
uni_packets_copy.to_csv('uni_packets.csv',index=False)
